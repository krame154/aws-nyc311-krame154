# %% [markdown]
# # Day 23 In-Class Assignment: AWS Learner Lab Setup and Problem Framing
#
# **Use this notebook to guide your in-class work on Day 23.**
#
# You will work in **small groups** to:
# - Confirm AWS Learner Lab access
# - Identify key console areas (S3, Athena, SageMaker AI)
# - Translate a stakeholder prompt into technical questions and success metrics
# - Document your findings in a "problem brief" that will guide your Week 1 work <- **update this when we finalize the Day 24 activities!!!**
#
# **At the end of class, you will submit this notebook to D2L.**

# %% [markdown]
# > **Name (FIRST and LAST):** _delete this text and type your name here before submitting this notebook_

# %% [markdown]
# ---
#
# ## Learning objectives
#
# By the end of this class period, you should be able to:
#
# - **Access** the AWS Academy Learner Lab and locate key services (S3, Athena, SageMaker AI).
# - **Explain** what you saw in the console and why each service matters for this module.
# - **Translate** a stakeholder prompt into concrete business and technical questions.
# - **Define** success metrics for a realistic analytics project.
# - **Document** your problem framing in a brief that guides Week 1–3 work.

# %% [markdown]
# ---
#
# ## Table of contents
#
# 1. [AWS Learner Lab access check](#access)
# 2. [Console orientation notes](#orientation)
# 3. [Stakeholder scenario and translation](#scenario)
# 4. [Problem brief (core deliverable)](#brief)

# %% [markdown]
# - - -
#
# <a id="access"></a>
#
# ## 1. AWS Learner Lab access check
#
# We did this together as a class, but it's provided here as a reference for you to check your access and console orientation if you had any issues during class or want to review later.
#
# ### Guided steps (from live demo):
#
# 1. Use your AWS Academy invite to open the course or, if you already accepted the invite, go to https://awsacademy.instructure.com/courses/ and click on the course card for this class.
# 2. Click **Learner Lab** → **Start Lab**.
# 3. Wait for the lab status to show **Running** (you'll see a green light and a countdown timer).
# 4. Once running, click **AWS Console** to open the main console.
# 5. In the top-left, note your **region** (e.g., `us-east-1`, `us-west-2`).

# %% [markdown]
# - - -
#
# <a id="orientation"></a>
#
# ## 2. Console orientation notes
#
# As a class we took a brief **guided tour** of the console. At this stage we are *looking* and *learning*, **not** creating or launching anything yet.
#
# ### During the instructor demo, you hopefully made note of the following for each of the services we visited:
#
# **S3 (Storage):**
# - Where S3 appears in the console (search bar or services menu)
# - What you understand S3 is for
# - Any question you have about how data would get into S3

# %% [markdown]
# > **2.1 S3 observations:**
# > _Any notes you want to record:_

# %% [markdown]
# **Athena (Serverless SQL):**
# - Where Athena appears in the console
# - What you understand Athena does
# - How you think it connects to S3

# %% [markdown]
# > **2.2 Athena observations:**
# > _Any notes you want to record:_

# %% [markdown]
# **SageMaker AI (Machine Learning):**
# - Where SageMaker AI appears in the console
# - What you understand SageMaker AI is for

# %% [markdown]
# > **2.3 SageMaker AI observations:**
# > _Any notes you want to record:_

# %% [markdown]
# - - -
#
# <a id="scenario"></a>
#
# ## 3. Stakeholder scenario and translation
#
# Now you'll translate a **realistic stakeholder prompt** into technical questions and success metrics.
#
# ### Your scenario:
#
# Your group has been assigned one of the following. **Note it below:**
#
# **Option A – Support Tickets:**
# A **product manager** says: "We're losing support tickets to escalation. How bad is it? What patterns should we look at?"
#
# **Option B – Call Center:**
# An **operations lead** says: "We seem to have inconsistent call volume across regions. How do we know which regions will have high call volume so we can staff appropriately?"
#
# > **3.1 Which scenario did your group get?**
# >
# Option A

# %% [markdown]
# ### Assumed dataset:
#
# For either scenario, you can assume you have access to realistic, multi-table data:
#
# - **Tickets/Calls table:** ID, type, creation date, resolution time, region, escalated?, agent assigned, duration
# - **Users table:** ID, region, customer segment, tenure
# - **Interactions table:** ticket/call ID, timestamp, agent notes, duration, sentiment (optional)
#
# You can assume this data is in S3 and you can query it with Athena.

# %% [markdown]
# ### Translation task:
#
# Chat with your group and brainstorm answers to the following. For this phase, the goal is to get some ideas down, so don't limit yourself to "getting it right" at this point. You can shape your ideas as you discuss and develop your problem brief in Part 4.

# %% [markdown]
# > **3.2 Restate the stakeholder question in plain language (your own words):**
# > _Your group's answer:_
#
# - The product manager wants to understand how serious the issue of support ticket escalations is. They want to know how often tickets are being escalated and whether there are any noticeable trends or common factors causing those escalations.
#
# > **3.3 List 2–3 (or more) specific technical questions you could answer with SQL queries:**
# > _Example: "What is the count of escalated vs. non-escalated tickets per week by region?"_
#
# 1)What is the total number and percentage of escalated tickets compared to non-escalated tickets over time ?
# 2)Which ticket categories, issue types, or product features have the highest escalation rates?
#
# >
# > **3.4 Describe what a "good analysis" would produce for the stakeholder:**
# > _E.g., a table they can read, a visualization, a prediction?_
#
# -Summary table showing the number and percentage of escalated vs. non-escalated tickets
# -Breakdown by category/team/region to identify where escalations are most common

# %% [markdown]
# - - -
#
# <a id="brief"></a>
#
# ## 4. Problem brief (core deliverable)
#
# Now synthesize your group's thinking into a one-page **problem brief** that could guide your work if you were to proceed with the project using AWS services.
#
# ### Brief template:
#
# Fill in each section below. This idea is that this document could serve as a reference document for writing SQL and validating results.

# %% [markdown]
# ### Stakeholder context
#
# _2–3 sentences on who is asking, why it matters, and what success looks like to them._
#
# -A product manager wants to understand how serious ticket escalations are and what patterns may be causing them. This matters because high escalations can hurt customer satisfaction and cause loss in revenue.

# %% [markdown]
# ### Business question
#
# _One primary question in plain language. Avoid jargon; imagine explaining it to someone outside your company._
#
# How serious is the ticket escalation issue, and what trends are causing it?

# %% [markdown]
# ### Technical questions for S3 + Athena
#
# _2–3 questions that could be answered with SQL aggregations, joins, filters, or window functions._
#
# > 1. **Question 1:**  What is the number and percentage of escalated tickets over time?
# > 2. **Question 2:**  Which ticket categories or teams have the highest escalation rates?
# > 3. **Question 3:** (optional)

# %% [markdown]
# ### Success metrics
#
# _At least 3–4 concrete criteria for "done." Examples: specific aggregations, a visualization, query performance, ability to re-run when data updates._
#
# > 1. **Metric 1:**  Table showing escalation counts and rates
# > 2. **Metric 2:**  Breakdown by category or team
# > 3. **Metric 3:**  Simple chart showing trends over time
# > 4. **Metric 4:** (optional)

# %% [markdown]
# ### Risks and assumptions
#
# _What might go wrong? What are you assuming about the data structure, quality, or availability?_
#
# > **Your answer:**
# > This assumes the data provided is accurate . Risks include missing data or inconsistent ticket labels.

# %% [markdown]
# ---
#
# ## 5. Reflection and wrap
#
# Before you submit, take a moment to reflect on your problem framing.
#
# > **5.1 Are your technical questions specific enough that you could write SQL for them?**
# > _Yes / No / Sort of?_
# >  Yes
# > **5.2 Do your success metrics actually define "done"? Would a stakeholder agree?**
# > _Yes / No / We think so_
# >  Think so

# %% [markdown]
# - - -
#
# ### Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page. Go to the In-class assignments section, find the appropriate submission link, and upload it there.
#
# See you in class!

# %% [markdown]
# ---
# © Copyright 2026, The Department of Computational Mathematics, Science and Engineering at Michigan State University.
